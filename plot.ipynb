# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
error = np.loadtxt('chart.txt')
epoch=np.linspace(0,len(error),len(error))
print(epoch)
# Out:
# [0.00000000e+00 1.00032268e+00 2.00064537e+00 ... 3.09799935e+03
#  3.09899968e+03 3.10000000e+03]

# %%
plt.figure(figsize=(8,6))  
plt.xlabel("EPOCH")     
plt.ylabel("Error")        
plt.title("XOR Binary")      
plt.plot(epoch,error)           
plt.show()
